# %%
##### Oracle_Automation_V16.ipynb
# OracleAutomation/Oracle_Automation_V16.ipynb

version = "Version 20"



version_details = """

# # Version - 20:
# assign custom tkinter instead of tkinter                  -ok      29.07.2024


# # Version - 19:
# Close oracle software before download OHD, ILS and M_Trans-ok      29.07.2024
# Open Oracle browser before download OHD, ILS and M_Transac ok      29.07.2024

# # Version - 18:
# if log in fail, then try again after caps lock off ------- ok      27.07.2024

# # Version - 17:
# Set 02 Default Password----------------------------------- ok      26.07.2024

# # Version - 16:
# Update KPI button activate-------------------------------

# # Version - 15:
# Send Shift Report button activate --------------------------------------------(Partially Ok)------ 


# # Version - 14:
# Change the icon of paddy field, ------------------------- ok       08.07.2024
# Chage the icon of task bar------------------------------- ok       08.07.2024
# Shorten and create relative path for both excel file----- ok       08.07.2024

# # Version - 13:
# Create a Temporary folder in root folder ---------------- ok       06.07.2024
# Version Details file create in Temporary Folder --------- ok       06.07.2024
# Pending Improvement file create in Temporary Folder ----- ok       06.07.2024
# File Details file create in Temporary Folder ------------ ok       06.07.2024

# Shorten the File path as Root Folder Type of 
# - Inspectioin7 by ripon --------------------------------- ok       05.07.2024


# # Version - 12:
# Bug Fixing of File Info -----------------------  -------- ok       05.07.2024

# # Version - 11: ----------------------------------------- ok       
# Added following Button 
#        "Send Shift Report",
#        "Send Daily Report",
#        "Send Monthly Report",
#        "Send Yearly Report",
#        "Send Up to Date Report",
#        "KPI Update",
#        "Check KPI",      
#        "Check Production Report"
#        "Manpower"


# # Version - 10:
# VBS File updated. 
#  - The cmd prompt hidden  -------------------------------- ok       29.06.2024
#  - Show and Auto Close msgbox of "Processing..." --------- ok       29.06.2024

# # Version - 9 :
# Bypass Again and Again entering log in credential -------- ok       15.05.2024 
# Required .bat file code added----------------------------- ok 
# Required .vbs file code added----------------------------- ok

# # Version - 8 :
# Arrange buttons basis num of columns in logged in window - ok       05.05.2024
# Oracle software close feature added----------------------- ok       05.05.2024
# Close Dedicated Browser----------------------------------- ok       05.05.2024
# Restart Browser ------------------------------------------ ok       05.05.2024 

# # Version - 7 :
# Created Check File Details ------------------------------- ok       04.05.2024
# Created Check Version Details----------------------------- ok       04.05.2024
# Created Check Pending Improvement Details ---------------- ok       04.05.2024
# Resize logged_in_window geometry-------------------------- ok       04.05.2024   

# *** Version -6 Cleaned
# Simply Clean unwanted commented module from V6------------ ok       28.04.2024  

# *** Version-6
# Binding the OK button when "Download M_Trans." date putted ok       28.04.2024   
# Binding the OK button when "Download OHD" date putted----- ok       28.04.2024

# *** Version-5
# Automatic Monthly Date selected, Running and Previous ILS- ok       24.04.2024
# Binding the OK button when "Download ILS" date putted----- ok       24.04.2024 

# *** Version-4
# update Excel File. (check M_Transaction Feature )--------- ok       21.04.2024
# *Check M_Transaction* popup window and function adding---- ok       21.04.2024

***
# Using log in form and create db file also, --------------- ok 
# Registration option included. ---------------------------- ok 
# Password Change option added ----------------------------- ok 
# show logged in User name in window ----------------------- ok
# change Password window arranged. ------------------------- ok
# all program close if logout clicked ---------------------- ok
# enter button activating for log in make easy ------------  ok       30.03.2024
# if successfully log in then get the  user interface ------ ok       30.03.2024
# print the button name which button clicked --------------- ok       30.03.2024
# error: shortcut_path not declared ======================== solved   10.04.2024
# Log in Oracle System function activating ----------------- ok       10.04.2024
# show messagebox as per click------------------------------ ok       10.04.2024
# show again the root window after log in Oracle------------ ok       10.04.2024 
# Assaign Task for * create MO * button------------------ -- ok       10.04.2024
# Function make for Logged in Menu window hide and appear -- ok       11.04.2024
# All Button Structure using *Pass* created ---------------- ok       11.04.2024 
# Set default Username and Password ------------------------ ok       11.04.2024
# Create a Bypass Log in Button to direct log in ----------- ok       11.04.2024
# *Check Batch Report* popup window and function adding----- ok       12.04.2024
# *Downlaod OHD* popup window and function adding----------- ok       12.04.2024
# *Download ILS* popup window and function adding----------- ok       13.04.2024
# *Download M_Transaction* popup window and function adding- ok       13.04.2024
# *Check OHD* popup window and function adding-------------- ok       17.04.2024
# *Check OHD* read only problem of inspection by ripon file- ok       21.04.2024
# unwanted closing the main file *Apr production file.------ ok       21.04.2024 
# *Check ILS* popup window and function adding-------------- ok       21.04.2024

"""

pending_improvement_details = """
# # # Goal # # # 

# Activate Whatsapp daily report Send button----------------
# Activate Whatsapp monthly report Send button -------------
# Activate Whatsapp Yearly report send button --------------
# Activate Combine Check OHD, ILS, M_Transaction, OPM button 
# Create a copy of Production Report (New File) ------------
# Create a central file or system to get report from any date
# Create a system to modify and check KPI ------------------


# Resizing the popup window, login window------------------- 
# Making Sure the Dedicated Firefox browser is active ------
# Making Sure Oracle software is active before run command -
# Set a hotkey to stop command if it make in a wrong position --


# Change the icon of paddy field, ---------------------------
# Set a logo ------------------------------------------------
# All Project files path should be corrected and packaged ---
# Create an installation file--when installed, python, all libraries and others should be installed --

"""

# bat_file_code = """

# @echo off

# rem Set the path to your Miniconda installation
# set CONDA_PATH=C:\Users\USER\miniconda3

# rem Set the name of your virtual environment
# set ENV_NAME=myenv

# rem Set the path to your Jupyter Notebook file
# set NOTEBOOK_PATH=F:\Ripon\python\OracleAutomation\Oracle_Automation_V10.ipynb

# rem Activate the virtual environment
# call "%CONDA_PATH%\Scripts\activate.bat" %ENV_NAME%

# rem Run the Jupyter Notebook
# jupyter nbconvert --execute --to notebook --inplace "%NOTEBOOK_PATH%"

# rem Deactivate the virtual environment
# call "%CONDA_PATH%\Scripts\deactivate.bat"

# rem Show a message box indicating completion
# rem msg * "Jupyter Notebook execution completed!"


# """


bat_file_name = "OracleAutomation.bat"

# vbs_file_code = """

# Dim response
# Dim password
# Dim objShell, objExec, objWMIService, colProcessList

# ' Prompt the user for the password
# password = InputBox("Please enter the password:", "Password")

# If password = "1" Then
#     ' Execute the batch file silently
#     Set objShell = WScript.CreateObject("WScript.Shell")
#     objShell.Run """F:\Ripon\python\OracleAutomation\OracleAutomation.bat""", 0

#     ' Show the processing message
#      objShell.Popup "Processing, please wait...", 4, "Processing", 64

# '    objShell.Run "wscript.exe ""F:\Ripon\python\OracleAutomation\ShowMessage.vbs"" ' ""Processing, Please Wait..."" 1", 0, False
    
#     ' Wait for the batch file to complete (replace the Sleep with appropriate wait logic if needed)
# '    Do
# '        WScript.Sleep 1000
# '        Set objWMIService = GetObject("winmgmts:\\.\root\cimv2")
# '        Set colProcessList = objWMIService.ExecQuery("Select * from Win32_Process Where Name = 'cmd.exe'")
# '        If colProcessList.Count = 0 Then Exit Do
# '    Loop

#     Set objShell = Nothing
# Else
#     MsgBox "Incorrect password. Access denied."
# End If



# """

vbs_file_name = "OracleAutomation - Copy.vbs"
# ---------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------------------


import calendar
import datetime
import tkinter as tk

import customtkinter as ctk
from PIL import Image, ImageTk

from tkinter import messagebox
from tkinter.simpledialog import askstring
import pyautogui as pg
import time
import subprocess
import win32com.client
import sqlite3
import hashlib
import os

file_path = "Oracle_Automation_V8.ipynb"
project_folder_path = ""
current_dir = os.getcwd()
supportive_folder_path = os.path.join(current_dir, "Supportive Folder")
excel_file_path = os.path.join(supportive_folder_path, "DownloadedDataHandlebyRiponV8.xlsm")




# Function to toggle between dark and light mode---------------------------------------------------------------------------
# def switch_mode():
#     if switch_var.get() == 1:
#         ctk.set_appearance_mode("dark")
#     else:
#         ctk.set_appearance_mode("light")

# # Set the default appearance mode and color theme
# ctk.set_appearance_mode("dark")
# ctk.set_default_color_theme("dark-blue")

# --------------------------------------------------------------------------------------------------------------------------





# version_details = current_dir



import os

# Create a connection to the SQLite database
conn = sqlite3.connect('user.db')
c = conn.cursor()

# Create a table to store user information
c.execute('''CREATE TABLE IF NOT EXISTS users
             (username TEXT PRIMARY KEY, password TEXT)''')
conn.commit()

# Function to register a new user
def register():
    username = username_entry.get()
    password = password_entry.get()
    
    # Check if the username already exists
    c.execute("SELECT * FROM users WHERE username=?", (username,))
    if c.fetchone():
        messagebox.showerror("Error", "Username already exists. Please choose a different one.")
    else:
        # Hash the password before storing it
        hashed_password = hashlib.sha256(password.encode()).hexdigest()
        c.execute("INSERT INTO users (username, password) VALUES (?, ?)", (username, hashed_password))
        conn.commit()
        messagebox.showinfo("Success", "Registration successful.")

# ----------------------------------------------------- ok start---------------------------------------


# Define global variables to store the credentials
logged_in_username = None 
logged_in_password = None 


# Function to check and turn off Caps Lock
def turn_off_caps_lock():
    hllDll = ctypes.WinDLL("User32.dll")
    VK_CAPITAL = 0x14
    if hllDll.GetKeyState(VK_CAPITAL):
        # Turn off Caps Lock
        hllDll.keybd_event(VK_CAPITAL, 0, 0x01, 0)
        hllDll.keybd_event(VK_CAPITAL, 0, 0x03, 0)

# Modify the login function to store credentials after successful authentication
def login(event=None):
    global logged_in_username, logged_in_password

    username = username_entry.get()
    password = password_entry.get()

    # Hash the provided password
    hashed_password = hashlib.sha256(password.encode()).hexdigest()
    # Check if the username and password match
    c.execute("SELECT * FROM users WHERE username=? AND password=?", (username, hashed_password))
    if c.fetchone():
        messagebox.showinfo("Success", "Login successful. Let's Go")
        # Store the credentials
        logged_in_username = username
        logged_in_password = password
        show_logged_in_menu(username)
        window.withdraw()  # Hide the login window after successful login
    else:
        # If login not successful, check if Caps Lock is on and turn it off if needed
        turn_off_caps_lock()
        
        # Try to log in again
        username = username_entry.get()  # Get the username and password again
        password = password_entry.get()
        hashed_password = hashlib.sha256(password.encode()).hexdigest()
        c.execute("SELECT * FROM users WHERE username=? AND password=?", (username, hashed_password))
        if c.fetchone():
            messagebox.showinfo("Success", "Login successful. Let's Go")
            # Store the credentials
            logged_in_username = username
            logged_in_password = password
            show_logged_in_menu(username)
            window.withdraw()  # Hide the login window after successful login
        else:
            messagebox.showerror("Error", "Invalid username or password.")

# Modify the login function to store credentials after successful authentication
# def login(event = None ):
#     global logged_in_username, logged_in_password
#     username = username_entry.get()
#     password = password_entry.get()

    
#     # Hash the provided password
#     hashed_password = hashlib.sha256(password.encode()).hexdigest()
#     # Check if the username and password match
#     c.execute("SELECT * FROM users WHERE username=? AND password=?", (username, hashed_password))
#     if c.fetchone():
#         messagebox.showinfo("Success", "Login successful. Let's Go")
#         # Store the credentials
#         logged_in_username = username
#         logged_in_password = password
#         show_logged_in_menu(username)
#         window.withdraw()  # Hide the login window after successful login
#     else:
#         messagebox.showerror("Error", "Invalid username or password.")

# Function to reuse stored credentials for another website or software
def reuse_credentials():
    global logged_in_username, logged_in_password
    if logged_in_username and logged_in_password:
        # Use the stored credentials to log in to another website or software
        # Replace this with your automation code to log in to the other software
        print("Logging in with stored credentials:")
        print("Username:", logged_in_username)
        print("Password:", logged_in_password)
    else:
        print("No stored credentials found. Please log in first.")

# --------------------------- Bypass Login using Username 5638 -----------------------

        
# --------------------------- Bypass Login using Username 5638 -----------------------
# Modify the login function to automatically fill in the username and trigger login
# Function to bypass login using the predefined username and passwords
def bypass_login():
    username = "5638"  # Set the username to "5638"
    password1 = "ripon"  # First default password
    password2 = "Ripon"  # Second default password
    
    # # Trigger login with the first password
    # if not login_with_credentials(username, password1):
    #     # If the first password fails, try the second password
    #     if not login_with_credentials(username, password2):
    #         # If both passwords fail, show an error message
    #         messagebox.showerror("Error", "Invalid username or password.")

    # Trigger login with the first password
    if login_with_credentials(username, password1):
        print(f"Logged in with password: {password1}")
    elif login_with_credentials(username, password2):
        print(f"Logged in with password: {password2}")
    else:
        # If both passwords fail, show an error message
        messagebox.showerror("Error", "Invalid username or password.")
        print("Login failed with both passwords.")

# Function to log in with specific credentials
def login_with_credentials(username, password):
    global logged_in_username, logged_in_password
    
    # Hash the provided password
    hashed_password = hashlib.sha256(password.encode()).hexdigest()
    
    # Check if the username and password match
    c.execute("SELECT * FROM users WHERE username=? AND password=?", (username, hashed_password))
    if c.fetchone():
        # messagebox.showinfo("Success", "Login successful. with ID 5638")  # Log in message disabled
        
        # Store the credentials
        logged_in_username = username
        logged_in_password = password
        show_logged_in_menu(username)
        window.withdraw()  # Hide the login window after successful login
        return True
    else:
        # messagebox.showerror("Error", "Invalid username or password.")
        return False


# --------------------------------------------------------------------------------------
# Function to open the Excel file
def open_excel_file(file_path):
    try:
        subprocess.Popen(['C:\\Program Files\\Microsoft Office\\root\\Office16\\EXCEL.EXE', file_path])
        print(f"Opening Excel file: {file_path}")
    except Exception as e:
        print(f"Error opening Excel file: {file_path}")
        print(e)


def show_logged_in_menu(username):
    global logged_in_window  # Make logged_in_window global

    def logout():
        logged_in_window.destroy()
        window.destroy()  # Close the main application window upon logout

    def on_closing():
        window.destroy()

    def show_change_password_window():
        change_password_window = tk.Toplevel(logged_in_window)
        change_password_window.title("Change Password")

        old_password_label = ctk.CTkLabel(change_password_window, text="Old Password:")
        old_password_label.grid(row=0, column=0, padx=10, pady=5, sticky=tk.W)
        old_password_entry = ctk.CTkEntry(change_password_window, show="*")
        old_password_entry.grid(row=0, column=1, padx=10, pady=5)

        new_password_label = ctk.CTkLabel(change_password_window, text="New Password:")
        new_password_label.grid(row=1, column=0, padx=10, pady=5, sticky=tk.W)
        new_password_entry = ctk.CTkEntry(change_password_window, show="*")
        new_password_entry.grid(row=1, column=1, padx=10, pady=5)

        change_button = ctk.CTkButton(change_password_window, text="Change Password",
                                  command=lambda: change_password(username, old_password_entry.get(), new_password_entry.get()))
        change_button.grid(row=2, columnspan=2, padx=10, pady=5)

    logged_in_window = ctk.CTkToplevel(window)
    logged_in_window.geometry('900x400')  # if use logged_in_window.geometry() then it will be wrap automoatically
    logged_in_window.after(201, lambda :logged_in_window.iconbitmap(icon_path))
    logged_in_window.title("Logged In Menu"+"                                                               "+ version)
    # Load the icon
    username_label = ctk.CTkLabel(logged_in_window, text="Welcome, " + username)
    username_label.grid(row=0, columnspan=2, padx=10, pady=5)

    def switch_mode():
        if switch_var.get() == 1:
            ctk.set_appearance_mode("dark")
        else:
            ctk.set_appearance_mode("light")
    
    # Set the default appearance mode and color theme
    # ctk.set_appearance_mode("dark")
    ctk.set_default_color_theme("dark-blue")
    

    # Add a switch to toggle dark and light mode
    switch_var = ctk.IntVar(value=1)  # Default is dark mode
    mode_switch = ctk.CTkSwitch(logged_in_window, text="Select Mode", variable=switch_var, onvalue=1, offvalue=0, command=switch_mode)
    mode_switch.grid(row = 0 , columnspan = 4, padx = 10, pady = 5)
    # ---------------------------------------------------------------------------------------------

    buttons = [
        "Log in Oracle Server",
        "Create MO",
        "Create Batch Posting",
        "Check Batch Report",
        "Download OHD",
        "Check OHD",
        "Download ILS",
        "Check ILS",
        "Download M_Transaction",
        "Check M_Transaction",

        "Close Oracle Software",
        # "Close Dedicated Browser",
        # "Restart Dedicated Browser",
        # "",
        # "",
        "Send Shift Report",
        # "Send Daily Report",
        # "Send Monthly Report",
        # "Send Yearly Report",
        # "Send Up to Date Report",
        
        # "Check Production Report",
        # "Manpower",       
        "KPI Update",
        "Check KPI",

        # "",     
        # "File Info",
        "Version Details",
        "Pending Improvement",

        "",       
        "Change Password",  # Added Change Password button
        "Logout",
        "",
        
    ]

    # Calculate maximum button width
    max_button_width = max(len(button_name) for button_name in buttons)

    num_buttons = len(buttons)
    num_columns = 4
    num_rows = (num_buttons + num_columns - 1) // num_columns  # Calculate number of rows needed

    for i, button_name in enumerate(buttons):
        if button_name == "Change Password":
            button = ctk.CTkButton(logged_in_window, text=button_name, width=max_button_width, command=show_change_password_window)
        elif button_name == "Logout":
            button = ctk.CTkButton(logged_in_window, text=button_name, width=max_button_width, command=logout)
        else:
            button = ctk.CTkButton(logged_in_window, text=button_name, width=max_button_width, command=lambda btn=button_name: button_click(btn))
        
        # Place buttons in two columns
        button.grid(row=i // num_columns + 1, column=i % num_columns, padx=10, pady=5)

    logged_in_window.protocol("WM_DELETE_WINDOW", on_closing)




# -*-------------------------------------------------------------------------------------------




# ------------------------------------- Change Password --------------------------------------

# Function to show the change password window

def show_change_password_window(username):
    change_password_window = tk.Toplevel(window)
    change_password_window.title("Change Password")
    
    old_password_label = ctk.CTkLabel(change_password_window, text="Old Password:")
    old_password_label.grid(row=0, column=0, padx=10, pady=5, sticky=tk.W)
    old_password_entry = ctk.CTkEntry(change_password_window, show="*")
    old_password_entry.grid(row=0, column=1, padx=10, pady=5)

    new_password_label = ctk.CTkLabel(change_password_window, text="New Password:")
    new_password_label.grid(row=1, column=0, padx=10, pady=5, sticky=tk.W)
    new_password_entry = ctk.CTkEntry(change_password_window, show="*")
    new_password_entry.grid(row=1, column=1, padx=10, pady=5)

    change_button = ctk.CTkButton(change_password_window, text="Change Password", command=lambda: change_password(username, old_password_entry.get(), new_password_entry.get()))
    change_button.grid(row=2, columnspan=2, padx=10, pady=5)

# Function to change password
def change_password(username, old_password, new_password):
    # Hash the old password
    hashed_old_password = hashlib.sha256(old_password.encode()).hexdigest()
    
    # Check if the provided old password is correct
    c.execute("SELECT * FROM users WHERE username=? AND password=?", (username, hashed_old_password))
    if c.fetchone():
        # Hash the new password before storing it
        hashed_new_password = hashlib.sha256(new_password.encode()).hexdigest()
        c.execute("UPDATE users SET password=? WHERE username=?", (hashed_new_password, username))
        conn.commit()
        messagebox.showinfo("Success", "Password changed successfully.")
    else:
        messagebox.showerror("Error", "Invalid old password.")




# ====================================== Log in Oracle Server ==========================================

# ====================================== Log in Oracle Server ==========================================

firefox_shortcut_path = r"C:\ProgramData\Microsoft\Windows\Start Menu\Programs\Mozilla Firefox.lnk"

def hide_logged_in_window():
    time.sleep(.5)
    logged_in_window.withdraw()  # Minimize the logged-in menu window
    time.sleep(.5)    

def appear_logged_in_window():
    logged_in_window.deiconify()



def open_firefox_dedicated_browser(firefox_shortcut_path):
    hide_logged_in_window()    
    try:
        subprocess.Popen([firefox_shortcut_path], shell=True)
        print("Mozilla Firefox is now opening...")
    except Exception as e:
        print(f"Error: {e}")


def log_in_oracle_server(username, password):
    open_firefox_dedicated_browser(firefox_shortcut_path)
    # Load the webpage
    time.sleep(8)

    # Login the website
    pg.write(username)
    pg.press("tab")
    pg.write(password)
    pg.press("tab")
    pg.press("enter")

    # Wait for the page to load 
    time.sleep(2)

    appear_logged_in_window()  # Restore the logged-in menu window


# ====================== Main Function ========================================================
# =============================================================================================

# ----------------------------------- Create MO -----------------------------------------------

# Select Create Move Order Element
def select_move_order_create():
    pg.press ("tab", presses = 12)
    pg.press ("enter")
    time.sleep (2)
    pg.press ("tab")
    pg.press ("enter")
    

# Wait for the software download 
def software_download():
    time.sleep(7)
    pg.hotkey ("alt","i")
    pg.press ("esc")
    pg.press ("enter")
    time.sleep (3)
    
# Fill Common Data
def fill_common_data():
    time.sleep(5)
    pg.press("tab")
    time.sleep(.2)
    pg.write ("Empty Bag for Packing Plant")
    time.sleep(.2)
    pg.press ("tab")
    
    #---------------------------------------
    time.sleep(.2)
    pg.write ("Move Order Transfer")
    pg.press ("tab")
        
    #----------------------------------------
    time.sleep(.2)
    pg.write ("CI - RM")
    pg.press ("tab")
       
    #----------------------------------------
    time.sleep(.2)
    pg.write ("CI - SFLR")
    pg.press ("tab", presses = 2)


# Main function of Create_MO()---------------------------
def create_mo():
    hide_logged_in_window()
    select_move_order_create()
    software_download()
    fill_common_data()
    time.sleep(2)
    # messagebox.showinfo("Create MO", "Creating MO...")  # Show message box after 2 seconds
    # time.sleep(.5)
    appear_logged_in_window()  # Restore the logged-in menu window
    

# ===================================================================================================
# ------------------------------ Create Batch Posting -----------------------------------------------


def create_batch_posting():
            hide_logged_in_window() # Minimize the Tkinter window
            # Select the web element for opening oracle software for creating batch
            pg.press("tab", presses=14)
            pg.press("enter")
            time.sleep(2)
            pg.press("tab", presses=3)
            pg.press("enter")
            
            # Wait for the software download 
            time.sleep(8)
            pg.hotkey("alt", "i")
            pg.press("esc")
            pg.press("enter")
            # messagebox.showinfo("Create Batch Posting", "Creating Batch Posting...")
            time.sleep(8)
            appear_logged_in_window()  # Restore the logged-in menu window




# ===================================================================================================
# ----------------------------------- Check Batch Report ------------------------------------------


# ----------------------------------- Check Batch Report  -------------------------------------------
def create_new_request_production_manager():
    time.sleep(1)
    pg.hotkey("alt", "v")
    pg.press("r")
    pg.hotkey("alt", "n")
    time.sleep(5)

def submit_form():
    pg.hotkey("alt", "m")
    time.sleep(3)
    pg.hotkey("alt", "n")
    time.sleep(3)
    pg.hotkey("alt", "i")

def refresh_and_get():
    time.sleep(1)
    pg.hotkey("alt", "r")
    time.sleep(2)
    pg.hotkey("alt", "p")

def check_batch_report(batch_report_from_date, batch_report_to_date):
    
    create_batch_posting()
    hide_logged_in_window() # Minimize the Tkinter window
    create_new_request_production_manager()
    pg.write("SSGIL Packer Wise Bag Cement Production")
    pg.press("tab")
    time.sleep(2)
    pg.write(batch_report_from_date)
    time.sleep(.5)
    pg.press("tab")
    pg.write(batch_report_to_date)
    time.sleep(.5)
    pg.hotkey("alt", "o")
    time.sleep(1)

    submit_form()
    refresh_and_get()
    time.sleep(2)
    print("Checking Packer wise batch report.")  
    
    # messagebox.showinfo("Check Batch Report", "Checking Batch Report...")
    appear_logged_in_window()  # Restore the logged-in menu window

# ----------------------------------- Download OHD --------------------------------------------------
    
def download_OHD_report(download_OHD_report_date):
    create_batch_posting()
    hide_logged_in_window() # Minimize the Tkinter window
    create_new_request_production_manager()
    pg.write("SSGIL Item Onhand Details")
    pg.press("tab")
    time.sleep(2)
    pg.write(download_OHD_report_date)
    time.sleep(.5)
    pg.hotkey("ctrl", "c")
    time.sleep(1)
    pg.hotkey("alt", "o")
    time.sleep(1)
    submit_form()
    time.sleep(5)
    refresh_and_get()
    
    print("Downloading the On Hand Details ")
    # messagebox.showinfo("Download OHD", "Download OHD...")
    time.sleep(1)
    appear_logged_in_window()  # Restore the logged-in menu window
    

# ----------------------------------- Download ILS --------------------------------------------------

def create_new_request_inventory():
    time.sleep(1)
    pg.hotkey("alt", "v")
    pg.press("r")
    pg.hotkey("alt", "n")
    time.sleep(5)

def download_ils_report(download_ils_from_date, download_ils_to_date):
    # download_ils()
    time.sleep(1)
    hide_logged_in_window() # Minimize the Tkinter window
    select_move_order_create()
    software_download()
    time.sleep(5)
    create_new_request_inventory()

    pg.write("SSGIL Item Ledger Summury")
    time.sleep(.5)
    pg.press("tab")
    time.sleep(2)
    pg.write(download_ils_from_date)
    time.sleep(.5)
    pg.press("tab")
    pg.write(download_ils_to_date)  
    time.sleep(.5)
    pg.press("tab", presses = 3)
    pg.write("CI - SFLR")
    # pg.hotkey("ctrl", "c")
    time.sleep(1)
    pg.hotkey("alt", "o")
    time.sleep(1)
    submit_form()
    time.sleep(16)
    refresh_and_get()
    
    
    print("Downloading the Item Ledger Summery ")
    print(f'From Date: {download_ils_from_date} , To Date: {download_ils_to_date}')
    # messagebox.showinfo("Download ILS", "Download ILS...")
    time.sleep(1)
    appear_logged_in_window()  # Restore the logged-in menu window

# ----------------------------------- Download M Transaction -------------------------------------------

def select_m_transaction():
    pg.press ("tab", presses = 12)
    pg.press ("enter")
    time.sleep (1)
    pg.press ("tab", presses = 3)
    pg.press ("enter")

def fill_common_data_for_m_transaction(download_m_transaction_from_date, download_m_transaction_to_date):
    pg.write(download_m_transaction_from_date)
    time.sleep(.5)
    pg.press("tab")
    pg.write(download_m_transaction_to_date)
    time.sleep(.5)
    pg.press("tab")
    time.sleep(.5)
    pg.press("tab", presses = 7)
    pg.write("Job or Schedule")
    time.sleep(.5)
    pg.hotkey("alt", "i")
    time.sleep(1)
    pg.hotkey("alt", "f")
    time.sleep(.1)
    pg.press("e")
    time.sleep(5)
    pg.hotkey("alt", "o")
    
    


def download_m_transaction_report(download_m_transaction_from_date, download_m_transaction_to_date):
    hide_logged_in_window()
    select_m_transaction()
    software_download()
    time.sleep(5)
    fill_common_data_for_m_transaction(download_m_transaction_from_date, download_m_transaction_to_date)
    time.sleep(15)
    # messagebox.showinfo("Create MO", "Creating MO...")  # Show message box after 2 seconds
    # time.sleep(.5)
    appear_logged_in_window()  # Restore the logged-in menu window



# ----------------------------------- check OHD --------------------------------------------------

import os
import win32com.client

def check_OHD_run_excel_macro(excel_file_path, macro_name):
    try:
        xl = win32com.client.GetActiveObject("Excel.Application")
    except:
        xl = win32com.client.Dispatch("Excel.Application")

    xl.Visible = True  # Set to False if you don't want Excel to be visible during execution

    try:
        workbook = xl.Workbooks.Open(excel_file_path)
        xl.Application.Run(macro_name)
        workbook.Close(SaveChanges=True)  # SaveChanges=True saves changes without prompting
        print("Check OHD Macro executed successfully.")
    except Exception as e:
        print(f"Error: {e}")
    # finally:
    #     xl.Quit()

# def check_OHD():
#     supportive_folder_path = os.path.join(project_folder_path, "Supportive Folder")
#     excel_file_path = r"F:\Ripon\python\OracleAutomation\Supportive Folder\DownloadedDataHandlebyRipon.xlsm"
#     macro_name = "GetLatestOHDandTransferData"
#     check_OHD_run_excel_macro(excel_file_path, macro_name)
    
def check_OHD():
    # excel_file_path = os.path.join(supportive_folder_path, "DownloadedDataHandlebyRipon.xlsm")
    macro_name = "GetLatestOHDandTransferData"
    check_OHD_run_excel_macro(excel_file_path, macro_name)



# check_OHD()


# ----------------------------------- check ILS --------------------------------------------------



import os
import win32com.client

def check_ILS_run_excel_macro(excel_file_path, macro_name):
    try:
        xl = win32com.client.GetActiveObject("Excel.Application")
    except:
        xl = win32com.client.Dispatch("Excel.Application")

    xl.Visible = True  # Set to False if you don't want Excel to be visible during execution

    try:
        workbook = xl.Workbooks.Open(excel_file_path)
        xl.Application.Run(macro_name)
        workbook.Close(SaveChanges=True)  # SaveChanges=True saves changes without prompting
        print("Check ILS Macro executed successfully.")
    except Exception as e:
        print(f"Error: {e}")
    # finally:
    #     xl.Quit()

def check_ILS():
    # excel_file_path = os.path.join(supportive_folder_path, "DownloadedDataHandlebyRipon.xlsm")
    macro_name = "GetLatestILSandTransferData"
    check_ILS_run_excel_macro(excel_file_path, macro_name)
    

# check_ILS()

# ----------------------------------- check M_Transaction --------------------------------------------------

import os
import win32com.client

def check_M_Transaction_run_excel_macro(excel_file_path, macro_name):
    try:
        xl = win32com.client.GetActiveObject("Excel.Application")
    except:
        xl = win32com.client.Dispatch("Excel.Application")

    xl.Visible = True  # Set to False if you don't want Excel to be visible during execution

    try:
        workbook = xl.Workbooks.Open(excel_file_path)
        xl.Application.Run(macro_name)
        workbook.Close(SaveChanges=True)  # SaveChanges=True saves changes without prompting
        print("Check M_Transaction Macro executed successfully.")
    except Exception as e:
        print(f"Error: {e}")


def check_M_Transaction():
    # excel_file_path = os.path.join(supportive_folder_path, "DownloadedDataHandlebyRipon.xlsm")
    macro_name = "GetLatest_M_Transaction_andTransferData"
    check_M_Transaction_run_excel_macro(excel_file_path, macro_name)

# check_M_Transaction()

# ----------------------------------- Close Oracle Software ----------------------------------------

import psutil

def terminate_process(process_name):
    for proc in psutil.process_iter(['name']):
        if proc.info['name'] == process_name:
            proc.terminate()
            print(f"Process {process_name} has been terminated.")
            return
    print(f"Process {process_name} is not running.")

process_name = "jp2launcher.exe"
# terminate_process(process_name)

# ----------------------------------- close Dedicated Browser --------------------------------------------


import psutil

target_path = r"C:\Program Files (x86)\Mozilla Firefox\firefox.exe"

def terminate_dedicated_browser(target_path):

    try:
        for proc in psutil.process_iter(['pid', 'name', 'exe']):
            if 'firefox' in proc.info['name'].lower() and target_path in proc.info['exe']:
                psutil.Process(proc.info['pid']).terminate()
                print(f"Terminated Firefox process with PID {proc.info['pid']} and path {target_path}")
    except Exception as e:
        print(f"Error: {e}")

# terminate_dedicated_browser(target_path)
# ----------------------------------- Restart Dedicated Browser ------------------------------------------

# Open the dedicated browser
import subprocess

firefox_shortcut_path = r"C:\ProgramData\Microsoft\Windows\Start Menu\Programs\Mozilla Firefox.lnk"

def restart_dedicated_browser(shortcut_path):
    try:
        subprocess.Popen([shortcut_path], shell=True)
        print("Mozilla Firefox is now opening...")
    except Exception as e:
        print(f"Error: {e}")

# Example usage:
# restart_dedicated_browser(firefox_shortcut_path)


# ----------------------------------- Send Shift Report --------------------------------------------------



import os
import win32com.client

def send_shift_report_excel_macro(excel_file_path, macro_name):
    try:
        xl = win32com.client.GetActiveObject("Excel.Application")
    except:
        xl = win32com.client.Dispatch("Excel.Application")

    xl.Visible = True  # Set to False if you don't want Excel to be visible during execution

    try:
        workbook = xl.Workbooks.Open(excel_file_path)
        xl.Application.Run(macro_name)
        workbook.Close(SaveChanges=True)  # SaveChanges=True saves changes without prompting
        print("Check ILS Macro executed successfully.")
    except Exception as e:
        print(f"Error: {e}")
    # finally:
    #     xl.Quit()

def send_shift_report():
    excel_file_path = os.path.join(supportive_folder_path, "Jul 24 Shun Shing Cement Industries Ltd.xlsm.lnk")
    # "F:\Ripon\python\OracleAutomation\Supportive Folder\Jul 24 Shun Shing Cement Industries Ltd.xlsm.lnk"
    macro_name = "Send_To_WhatsApp"
    send_shift_report_excel_macro(excel_file_path, macro_name)
    

# send_shift_report()

# ----------------------------------- Send Shift Report --------------------------------------------------



import os
import win32com.client

def KPI_update_excel_macro(excel_file_path, macro_name):
    try:
        xl = win32com.client.GetActiveObject("Excel.Application")
    except:
        xl = win32com.client.Dispatch("Excel.Application")

    xl.Visible = True  # Set to False if you don't want Excel to be visible during execution

    try:
        workbook = xl.Workbooks.Open(excel_file_path)
        xl.Application.Run(macro_name)
        workbook.Close(SaveChanges=True)  # SaveChanges=True saves changes without prompting
        print("Check ILS Macro executed successfully.")
    except Exception as e:
        print(f"Error: {e}")
    # finally:
    #     xl.Quit()

def KPI_update():
    # excel_file_path = os.path.join(supportive_folder_path, "Jul 24 Shun Shing Cement Industries Ltd.xlsm.lnk")
    # "F:\Ripon\python\OracleAutomation\Supportive Folder\Jul 24 Shun Shing Cement Industries Ltd.xlsm.lnk"
    macro_name = "CopyMultipleKPISheets"
    send_shift_report_excel_macro(excel_file_path, macro_name)
    

# KPI_update()




# ----------------------------------- File Info --------------------------------------------------

project_folder_path= ""
file_details = "ABCD"

import os
import datetime
import ipynbname

# def create_file_with_details(folder_path, file_details):
# def create_file_with_details(folder_path):
def create_file_with_details(project_folder_path, file_details):
    # Ensure the Temporary folder exists
    temporary_folder_path = os.path.join(project_folder_path, "Temporary")
    if not os.path.exists(temporary_folder_path):
        os.makedirs(temporary_folder_path)

    # Create the full file path
    file_path = os.path.join(temporary_folder_path, "file_details.txt")

    ipynb_file_name = ipynbname.name()
    ipynb_file_path = ipynbname.path()

    file_details = f"File Name: {ipynb_file_name}\n" \
                    f"File Path: {ipynb_file_path}\n"

    # Write sample text to the file
    with open(file_path, "w") as file:
        file.write(file_details)
        
    # Open the file
    os.system(f"start {file_path}")



# file_details = "ABCD"

# import os
# import datetime
# import ipynbname

# # def create_file_with_details(folder_path, file_details):
# # def create_file_with_details(folder_path):
# def create_file_with_details(project_folder_path, file_details):
#     # Ensure the Temporary folder exists
#     temporary_folder_path = os.path.join(project_folder_path, "Temporary")
#     if not os.path.exists(temporary_folder_path):
#         os.makedirs(temporary_folder_path)

#     # Create the full file path
#     file_path = os.path.join(temporary_folder_path, "file_details.txt")

#     ipynb_file_name = ipynbname.name()
#     ipynb_file_path = ipynbname.path()

#     file_details = f"File Name: {ipynb_file_name}\n" \
#                     f"File Path: {ipynb_file_path}\n"

#     # Write sample text to the file
#     with open(file_path, "w") as file:
#         file.write(file_details)
        
#     # Open the file
#     os.system(f"start {file_path}")
    



# import os
# import datetime
# import ipynbname

# def create_file_with_details(folder_path):
#     # Create the full file path
#     txt_file_path = os.path.join(folder_path, "file_details.txt")
#     ipynb_file_path = ipynbname.path()
#     # Get file name
#     txt_file_name = os.path.basename(txt_file_path)
#     ipynb_file_name = ipynbname.name()
    
#     # Get file's full path
#     txt_full_path = os.path.abspath(txt_file_path)
#     ipynb_full_path = ipynbname.path()
    
#     # Write file details to a string
#     file_details = f"File Name: {ipynb_file_name}\n" \
#                    f"Full Path: {ipynb_full_path}\n"
    
#     # Write file details to a text file
#     with open(txt_file_path, "w") as file:
#         file.write(file_details)
    
#     # Get last modified time
#     last_modified_time = os.path.getmtime(ipynb_file_path)
    
#     # Convert last modified time to a readable format
#     last_modified_time_str = datetime.datetime.fromtimestamp(last_modified_time).strftime('%Y-%m-%d %H:%M:%S')
    
#     # Append last modified time to the file
#     with open(txt_file_path, "a") as file:
#         file.write(f"Last Modified Time: {last_modified_time_str}\n")
    
#     # Open the file using the default text editor
#     os.system(f"start {txt_file_path}")

# Example usage:
# project_folder_path = "./"
# create_file_with_details(project_folder_path)




# ----------------------------------- Version Details --------------------------------------------------

import os

def open_version_details_file(folder_path, version_details):
    # Ensure the Temporary folder exists
    temporary_folder_path = os.path.join(folder_path, "Temporary")
    if not os.path.exists(temporary_folder_path):
        os.makedirs(temporary_folder_path)

    # Create the full file path in the Temporary folder
    file_path = os.path.join(temporary_folder_path, "version_details.txt")

    # Write sample text to the file
    with open(file_path, "w") as file:
        file.write(version_details)
        
    # Open the file
    os.system(f"start {file_path}")  # This will open the file using the default text editor

# Example usage
# version_details = "Sample version details text."
# project_folder_path = "./"
# open_version_details_file(project_folder_path, version_details)



# ----------------------------------- Pending Improvement Details --------------------------------------------------

import os

def open_pending_improvement_details_file(folder_path, pending_improvement_details):
    # Ensure the Temporary Folder exists
    temporary_folder_path = os.path.join(folder_path, "Temporary")
    if not os.path.exists(temporary_folder_path):
        os.makedirs(temporary_folder_path)

    # Create the full file path in the Temporary folder
    file_path = os.path.join(temporary_folder_path, "pending_improvement_details.txt")

    # Write sample text to the file
    with open(file_path, "w") as file:
        file.write(pending_improvement_details)

    # Open the file
    os.system (f"start {file_path}")    # This will open the file using the default text editor


# Example usage
# pending_improvement_details = "Sample version details text."
# project_folder_path = "./"
# open_pending_improvement_details_file(project_folder_path, pending_improvement_details)



# ==============================================================================================================
# Create a tkinter window
window = ctk.CTk()
# window.geometry('400x300')
window.title("Login System")
# global icon_path
icon_path = os.path.join(supportive_folder_path, "Ripon_logo.ico")

window.iconbitmap(icon_path)




def button_click(button_name):
    global logged_in_username, logged_in_password
    if button_name == "Log in Oracle Server":
        if logged_in_username and logged_in_password:
            log_in_oracle_server(logged_in_username, logged_in_password)
        else:
            messagebox.showerror("Error", "Please log in first.")

    elif button_name == "Create MO":  
       create_mo()

    elif button_name == "Create Batch Posting":        
        create_batch_posting()
        
    # ===================================================================================================
    # ----------------------------------- Check Batch Report --------------------------------------------     
    
    elif button_name == "Check Batch Report":
        # Create a popup window for entering date range
        popup_window = tk.Toplevel(window)
        popup_window.title("Enter Date Range For Check Batch Report")
        
        # Function to handle button click in popup window
        def ok_button_click():
            batch_report_from_date = batch_report_from_date_entry.get()
            batch_report_to_date = batch_report_to_date_entry.get()

            # Close the popup window
            popup_window.destroy()
            
            # Do something with the date range (e.g., pass it to a function)
            check_batch_report(batch_report_from_date, batch_report_to_date)
            
            print("Task completed. Batch report ready to view.")
            # messagebox.showinfo("Check Batch Report", "task completed. Batch report ready to view.")  # Show message box after 2 seconds
            
        
        # Labels and entry fields for from date and to date
        batch_report_from_date_label = ctk.CTkLabel(popup_window, text="From Date:")
        batch_report_from_date_label.grid(row=0, column=0, padx=10, pady=5, sticky=tk.W)
        batch_report_from_date_entry = ctk.CTkEntry(popup_window)
        batch_report_from_date_entry.grid(row=0, column=1, padx=10, pady=5)
        
        batch_report_to_date_label = ctk.CTkLabel(popup_window, text="To Date:")
        batch_report_to_date_label.grid(row=1, column=0, padx=10, pady=5, sticky=tk.W)
        batch_report_to_date_entry = ctk.CTkEntry(popup_window)
        batch_report_to_date_entry.grid(row=1, column=1, padx=10, pady=5)
        
        # OK button to confirm date range
        ok_button = ctk.CTkButton(popup_window, text="OK", command=ok_button_click)
        ok_button.grid(row=2, columnspan=2, padx=10, pady=5)
        

    # ===================================================================================================
    # ----------------------------------- Download OHD --------------------------------------------------
    
    elif button_name == "Download OHD":
        # Create a popup window for entering date range
        popup_window = tk.Toplevel(window)
        popup_window.title("Enter Date For Download On Hand Details Report")
        
        # Function to handle button click in popup window
        def download_OHD_button_click():
            download_OHD_report_date = download_OHD_report_date_entry.get()
            
            # Close the popup window
            popup_window.destroy()
            
            # Do something with the date range (e.g., pass it to a function)
            
            terminate_process(process_name) # close the Oracle Software if ruuning
            time.sleep(1)
            log_in_oracle_server(logged_in_username, logged_in_password)
            time.sleep(2)
            download_OHD_report(download_OHD_report_date)
            
            print("Task completed. Download On Hand Details report ready to view.")
            # messagebox.showinfo("Check Batch Report", "task completed. Batch report ready to view.")  # Show message box after 2 seconds

        # Function to set the date to yesterday
        def select_yesterday():
            yesterday = datetime.date.today() - datetime.timedelta(days=1)
            download_OHD_report_date_entry.delete(0, tk.END)
            download_OHD_report_date_entry.insert(0, yesterday.strftime("%d%b%Y"))

        # Function to set the date to today
        def select_today():
            today = datetime.date.today()
            download_OHD_report_date_entry.delete(0, tk.END)
            download_OHD_report_date_entry.insert(0, today.strftime("%d%b%Y"))
        
        # Labels and entry fields for report date
        download_OHD_report_date_label = ctk.CTkLabel(popup_window, text="On Date:")
        download_OHD_report_date_label.grid(row=0, column=0, padx=10, pady=5, sticky=tk.W)
        download_OHD_report_date_entry = ctk.CTkEntry(popup_window)
        download_OHD_report_date_entry.grid(row=0, column=1, padx=10, pady=5)
        
        # Button for selecting yesterday
        yesterday_button = ctk.CTkButton(popup_window, text="Yesterday", command=select_yesterday)
        yesterday_button.grid(row=1, column=0, padx=10, pady=5)

        # Button for selecting today
        today_button = ctk.CTkButton(popup_window, text="Today", command=select_today)
        today_button.grid(row=1, column=1, padx=10, pady=5)
        
        # OK button to confirm date selection
        ok_button = ctk.CTkButton(popup_window, text="OK", command=download_OHD_button_click)
        ok_button.grid(row=2, columnspan=2, padx=10, pady=5)
           
        hide_logged_in_window() # Minimize the Tkinter window
        
        # messagebox.showinfo("Download OHD Report", "Downloading OHD Report...")  # Show message box after 2 seconds
        print("Download OHD Report", "Downloading OHD Report...")  # Show message box after 2 seconds
    
        appear_logged_in_window()  # Restore the logged-in menu window
   
        pass


    # ===================================================================================================
    # ----------------------------------- Check OHD -----------------------------------------------------
    elif button_name == "Check OHD":
        check_OHD()
        # messagebox.showinfo(f"{button_name} Report", f"Downloading and {button_name} Report...")  # Show message box after 2 seconds
        
        pass


    # ===================================================================================================
    # ----------------------------------- Download ILS --------------------------------------------------
    
    elif button_name == "Download ILS":
        # Create a popup window for entering date range
        popup_window = tk.Toplevel(window)
        popup_window.title(f"Enter Date Range For {button_name} Report")
        
        # Function to handle button click in popup window
        def download_ils_button_click(download_ils_from_date, download_ils_to_date):
            # Close the popup window
            popup_window.destroy()
            
            # Do something with the date range (e.g., pass it to a function)
            
            terminate_process(process_name) # close the Oracle Software if ruuning
            time.sleep(1)
            log_in_oracle_server(logged_in_username, logged_in_password)
            time.sleep(2)
            download_ils_report(download_ils_from_date, download_ils_to_date)
            
            print("Task completed. ILS report ready to view.")
    
        # Function to bind the "OK" button action
        def bind_ok_button(event=None):
            download_ils_button_click(download_ils_from_date_entry.get(), download_ils_to_date_entry.get())
    
        # Function to set date range for previous month
        def select_previous_month():
            today = datetime.date.today()
            last_day_of_previous_month = today.replace(day=1) - datetime.timedelta(days=1)
            first_day_of_previous_month = last_day_of_previous_month.replace(day=1)
            download_ils_from_date = first_day_of_previous_month.strftime("%d%b%Y")
            download_ils_to_date = last_day_of_previous_month.strftime("%d%b%Y")
            download_ils_button_click(download_ils_from_date, download_ils_to_date)
            
        # Function to set date range for running month
        def select_running_month():
            today = datetime.date.today()
            first_day_of_running_month = today.replace(day=1)
            last_day_of_running_month = today.replace(day=calendar.monthrange(today.year, today.month)[1])
            download_ils_from_date = first_day_of_running_month.strftime("%d%b%Y")
            download_ils_to_date = last_day_of_running_month.strftime("%d%b%Y")
            download_ils_button_click(download_ils_from_date, download_ils_to_date)
    
        # Button for selecting previous month
        previous_month_button = ctk.CTkButton(popup_window, text="Previous Month", command=select_previous_month)
        previous_month_button.grid(row=0, column=0, padx=10, pady=5)
    
        # Button for selecting running month
        running_month_button = ctk.CTkButton(popup_window, text="Running Month", command=select_running_month)
        running_month_button.grid(row=0, column=1, padx=10, pady=5)
    
        # Labels and entry fields for from date and to date
        download_ils_from_date_label = ctk.CTkLabel(popup_window, text="From Date:")
        download_ils_from_date_label.grid(row=1, column=0, padx=10, pady=5, sticky=tk.W)
        download_ils_from_date_entry = ctk.CTkEntry(popup_window)
        download_ils_from_date_entry.grid(row=1, column=1, padx=10, pady=5)
    
        download_ils_to_date_label = ctk.CTkLabel(popup_window, text="To Date:")
        download_ils_to_date_label.grid(row=2, column=0, padx=10, pady=5, sticky=tk.W)
        download_ils_to_date_entry = ctk.CTkEntry(popup_window)
        download_ils_to_date_entry.grid(row=2, column=1, padx=10, pady=5)
    
        # OK button to confirm date range
        ok_button = ctk.CTkButton(popup_window, text="OK", command=bind_ok_button)
        ok_button.grid(row=3, columnspan=2, padx=10, pady=5)
    
        # Bind the Enter key to the "OK" button
        popup_window.bind("<Return>", bind_ok_button)
    # ===================================================================================================
    # ----------------------------------- Check ILS -----------------------------------------------------
    elif button_name == "Check ILS":
        check_ILS()
        # messagebox.showinfo(f"{button_name} Report", f"Downloading and {button_name} Report...")  # Show message box after 2 seconds
        
        pass
    

    # ===================================================================================================
    # ----------------------------------- Download M_Transaction ------------------------------------------
   
    elif button_name == "Download M_Transaction":
         
         
        # Create a popup window for entering date range
        popup_window = tk.Toplevel(window)
        popup_window.title(f"Enter Date Range For {button_name} Report")
        
        # Function to handle button click in popup window
        def download_m_transaction_button_click(download_m_transaction_from_date, download_m_transaction_to_date):
            # Close the popup window
            popup_window.destroy()
            
            # Do something with the date range (e.g., pass it to a function)
            
            terminate_process(process_name) # close the Oracle Software if ruuning
            time.sleep(1)
            log_in_oracle_server(logged_in_username, logged_in_password)
            time.sleep(2)
            download_m_transaction_report(download_m_transaction_from_date, download_m_transaction_to_date)
            
            print("Task completed. ILS report ready to view.")
        
        # Function to bind the "OK" button action
        def bind_ok_button(event=None):
            download_m_transaction_button_click(download_m_transaction_from_date_entry.get(), download_m_transaction_to_date_entry.get())
        
        # Function to set date range for previous month
        def select_previous_month():
            today = datetime.date.today()
            last_day_of_previous_month = today.replace(day=1) - datetime.timedelta(days=1)
            first_day_of_previous_month = last_day_of_previous_month.replace(day=1)
            download_m_transaction_from_date = first_day_of_previous_month.strftime("%d%b%Y")
            download_m_transaction_to_date = last_day_of_previous_month.strftime("%d%b%Y")
            download_m_transaction_button_click(download_m_transaction_from_date, download_m_transaction_to_date)
            
        # Function to set date range for running month
        def select_running_month():
            today = datetime.date.today()
            first_day_of_running_month = today.replace(day=1)
            last_day_of_running_month = today.replace(day=calendar.monthrange(today.year, today.month)[1])
            download_m_transaction_from_date = first_day_of_running_month.strftime("%d%b%Y")
            download_m_transaction_to_date = last_day_of_running_month.strftime("%d%b%Y")
            download_m_transaction_button_click(download_m_transaction_from_date, download_m_transaction_to_date)
        
        # Button for selecting previous month
        previous_month_button = ctk.CTkButton(popup_window, text="Previous Month", command=select_previous_month)
        previous_month_button.grid(row=0, column=0, padx=10, pady=5)
        
        # Button for selecting running month
        running_month_button = ctk.CTkButton(popup_window, text="Running Month", command=select_running_month)
        running_month_button.grid(row=0, column=1, padx=10, pady=5)
        
        # Labels and entry fields for from date and to date
        download_m_transaction_from_date_label = ctk.CTkLabel(popup_window, text="From Date:")
        download_m_transaction_from_date_label.grid(row=1, column=0, padx=10, pady=5, sticky=tk.W)
        download_m_transaction_from_date_entry = ctk.CTkEntry(popup_window)
        download_m_transaction_from_date_entry.grid(row=1, column=1, padx=10, pady=5)
        
        download_m_transaction_to_date_label = ctk.CTkLabel(popup_window, text="To Date:")
        download_m_transaction_to_date_label.grid(row=2, column=0, padx=10, pady=5, sticky=tk.W)
        download_m_transaction_to_date_entry = ctk.CTkEntry(popup_window)
        download_m_transaction_to_date_entry.grid(row=2, column=1, padx=10, pady=5)
        
        # OK button to confirm date range
        ok_button = ctk.CTkButton(popup_window, text="OK", command=bind_ok_button)
        ok_button.grid(row=3, columnspan=2, padx=10, pady=5)
        
        # Bind the Enter key to the "OK" button
        popup_window.bind("<Return>", bind_ok_button)     
        pass
    # ===================================================================================================
    # ----------------------------------- Check M_Transaction -----------------------------------------------------
    elif button_name == "Check M_Transaction":
        check_M_Transaction()
        # messagebox.showinfo(f"{button_name} Report", f"Downloading and {button_name} Report...")  # Show message box after 2 seconds
        
        pass

        # ===================================================================================================
    # ----------------------------------- Close Oracle Software -----------------------------------------------------
    elif button_name == "Close Oracle Software":
        terminate_process(process_name)
        # messagebox.showinfo(f"{button_name} Report", f"Downloading and {button_name} Report...")  # Show message box after 2 seconds
        
        pass

        # ===================================================================================================
    # ----------------------------------- Close Oracle Software -----------------------------------------------------
    elif button_name == "Close Dedicated Browser":
        terminate_dedicated_browser(target_path)
        # messagebox.showinfo(f"{button_name} Report", f"Downloading and {button_name} Report...")  # Show message box after 2 seconds
        
        pass



        # ===================================================================================================
    # ----------------------------------- Close Oracle Software -----------------------------------------------------
    elif button_name == "Restart Dedicated Browser":
        restart_dedicated_browser(firefox_shortcut_path)
        # messagebox.showinfo(f"{button_name} Report", f"Downloading and {button_name} Report...")  # Show message box after 2 seconds
        
        pass

        # ===================================================================================================
    # ----------------------------------- Send Shift Report -----------------------------------------------------
    elif button_name == "Send Shift Report":
        send_shift_report()
        # messagebox.showinfo(f"{button_name} Report", f"Downloading and {button_name} Report...")  # Show message box after 2 seconds
        
        pass
        
        # ===================================================================================================
    # ----------------------------------- Send Shift Report -----------------------------------------------------
    elif button_name == "KPI Update":
        KPI_update()
        # messagebox.showinfo(f"{button_name} Report", f"Downloading and {button_name} Report...")  # Show message box after 2 seconds
        
        pass

    
    # ===================================================================================================
    # ----------------------------------- File Info -----------------------------------------------------
    elif button_name == "File Info":
        # print_file_details(file_path)
        # create_file_with_details(folder_path, file_details)
        create_file_with_details(project_folder_path, file_details)
        # messagebox.showinfo(f"{button_name} Report", f"Downloading and {button_name} Report...")  # Show message box after 2 seconds
        
        pass

        # ===================================================================================================
    # ----------------------------------- Version Details -----------------------------------------------------
    elif button_name == "Version Details":
        
        # open_version_details_file(project_folder_path)
        open_version_details_file(project_folder_path, version_details)
        # messagebox.showinfo(f"{button_name} Report", f"Downloading and {button_name} Report...")  # Show message box after 2 seconds
        
        pass
    # ===================================================================================================
    # ----------------------------------- Pending Improvement -----------------------------------------------------
    elif button_name == "Pending Improvement":
        open_pending_improvement_details_file(project_folder_path, pending_improvement_details)
        # messagebox.showinfo(f"{button_name} Report", f"Downloading and {button_name} Report...")  # Show message box after 2 seconds
        
        pass


    # ============================================================================================
            
    else:
        print(f"Button clicked: {button_name}")
        messagebox.showinfo(f"{button_name}",f"Button clicked: {button_name}")




        
    # ============================================================================================
    # ============================================================================================
    # ============================================================================================



# Username label and entry
username_label = ctk.CTkLabel(window, text="Username:")
username_label.grid(row=0, column=0, padx=10, pady=5, sticky=tk.W)
username_entry = ctk.CTkEntry(window)
username_entry.grid(row=0, column=1, padx=10, pady=5)

username_entry.insert(0, "5638")  # Set the default username as "5638"


# Password label and entry
password_label = ctk.CTkLabel(window, text="Password:")
password_label.grid(row=1, column=0, padx=10, pady=5, sticky=tk.W)
password_entry = ctk.CTkEntry(window, show="*")
password_entry.grid(row=1, column=1, padx=10, pady=5)

password_entry.insert(0, "")  # Set the default password ""

password_entry.bind("<Return>", login)  # Bind the Enter key event to the login function

# Register and login buttons
register_button = ctk.CTkButton(window, text="Register", command=register)
register_button.grid(row=2, column=0, padx=10, pady=5)
login_button = ctk.CTkButton(window, text="Login", command=login)
login_button.grid(row=2, column=1, padx=10, pady=5)

# Add a bypass button to the GUI
bypass_button = ctk.CTkButton(window, text="Bypass Login", command=bypass_login)
bypass_button.grid(row=3, column=0, columnspan=2, padx=10, pady=5)



# -------------------------------------------------------------------------------------
# Function to schedule the bypass login after 1 seconds
def schedule_bypass_login():
    window.after(1000, bypass_login) # here 1000 means 1 second



# Schedule the bypass login after 5 seconds
# schedule_bypass_login()


# -------------------------------------------------------------------------------------


# Start the tkinter event loop
window.mainloop()
reuse_credentials()

# Close the connection to the database
conn.close()
# Out:
# Logged in with password: Ripon
# Logging in with stored credentials:
# Username: 5638
# Password: Ripon
