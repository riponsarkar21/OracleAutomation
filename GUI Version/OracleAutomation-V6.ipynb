# %%
# 22 mar 2024
# pypy/TKinterGui/GUI Version/OracleAutomation-V4.ipynb
# log in -------------------------------- ok - 17 mar 2024
# Create MO ----------------------------- ok - 17 mar 2024
# Create Batch -------------------------- ok - 17 mar 2024
# Check Batch Report------ - ------------ ok - 17 mar 2024
# Download OHD -------------------------- ok - 17 mar 2024
# Check OHD ----------------------------- Pending
# Download ILS -------------------------- ok - 17 mar 2024
# Check ILS ----------------------------- Pending
# Download M_Transaction ---------------- Pending
# Check M_Transaction ------------------- Pending
# Download OPM -------------------------- Pending
# Check OPM ----------------------------- Pending
# Add Faceplate for login credential ----


import tkinter as tk
from tkinter import messagebox
from tkinter.simpledialog import askstring
import pyautogui as pg
import time
import subprocess




# -----------------  User Level Variables List -----------------------------------------

# username = "5638"
# password = "Ripon"

batch_report_from_date = "17-mar24"
batch_report_to_date = "17-mar-24"

ils_date_from = "01-mar-24"
ils_date_to = "31-mar-24"

# ----------------- function used as Sub Function --------------------------------------


def open_firefox_dedicated_browser(shortcut_path):
    try:
        subprocess.Popen([shortcut_path], shell=True)
        print("Mozilla Firefox is now opening...")
    except Exception as e:
        print(f"Error: {e}")


def user_log_in(username, password):
    # Load the webpage
    time.sleep(8)

    # Login the website
    pg.write(username)
    pg.press("tab")
    pg.write(password)
    pg.press("tab")
    pg.press("enter")

    # Wait for the page to load 
    time.sleep(2)
# ----------------------------------- Activate the software -----------------------------------------------

import tkinter as tk
from tkinter import messagebox
username = ""
password = ""

def login(event=None):
    global username
    global password
    username = username_entry.get()
    password = password_entry.get()
    
    # Here, you can perform validation or authentication logic
    # For simplicity, let's just show a message box with the entered username and password
    # messagebox.showinfo("Login Info", f"Username: {username}\nPassword: {password}")
    print("Login Info", f"Username: {username}\nPassword: {password}")
    root.destroy()  # Close the root window after login

# Create main window
root = tk.Tk()
root.title("Login")

# Create labels and entries for username and password
tk.Label(root, text="Username:").grid(row=0, column=0, padx=10, pady=5)
username_entry = tk.Entry(root)
username_entry.grid(row=0, column=1, padx=10, pady=5)
username_entry.focus()  # Set focus to username entry by default

tk.Label(root, text="Password:").grid(row=1, column=0, padx=10, pady=5)
password_entry = tk.Entry(root, show="*")
password_entry.grid(row=1, column=1, padx=10, pady=5)

# Bind <Return> key event to login function
root.bind("<Return>", login)

# Create login button
login_button = tk.Button(root, text="Login", command=login)
login_button.grid(row=2, columnspan=2, padx=10, pady=10)

# Start the GUI event loop
root.mainloop()


print(username)

# ----------------------------------- log in  ------------------------------------------------------
def log_in():
    root.withdraw()  # Minimize the Tkinter window
    time.sleep(1)
    open_firefox_dedicated_browser(firefox_shortcut_path)
    user_log_in(username, password)
    root.deiconify()  # Show the Tkinter window after the login process completes
    # messagebox.showinfo("Login Info", f"Username: {username}\nPassword: {password}")
    

# ----------------------------------- Create MO -----------------------------------------------------
# ----------------------------------- Create MO -----------------------------------------------------
# Select Create Move Order Element
def select_move_order_create():
    pg.press ("tab", presses = 12)
    pg.press ("enter")
    time.sleep (1)
    pg.press ("tab")
    pg.press ("enter")
    

# Wait for the software download 
def software_download():
    time.sleep(5)
    pg.hotkey ("alt","i")
    pg.press ("esc")
    pg.press ("enter")
    time.sleep (3)
    
# Fill Common Data
def fill_common_data():
    time.sleep(5)
    pg.press("tab")
    time.sleep(.2)
    pg.write ("Empty Bag for Packing Plant")
    time.sleep(.2)
    pg.press ("tab")
    
    #---------------------------------------
    time.sleep(.2)
    pg.write ("Move Order Transfer")
    pg.press ("tab")
        
    #----------------------------------------
    time.sleep(.2)
    pg.write ("CI - RM")
    pg.press ("tab")
       
    #----------------------------------------
    time.sleep(.2)
    pg.write ("CI - SFLR")
    pg.press ("tab", presses = 2)



def create_mo():
    time.sleep(1)
    root.withdraw()  # Minimize the Tkinter window
    select_move_order_create()
    software_download()
    fill_common_data()
    # messagebox.showinfo("Create MO", "Creating MO...")
    time.sleep(1)
    root.deiconify()  # Show the Tkinter window after the login process completes

# ---------------------------------------- XXX -----------------------------------------------------
def create_new_request_inventory():
    time.sleep(1)
    pg.hotkey("alt", "v")
    pg.press("r")
    pg.hotkey("alt", "n")
    time.sleep(5)

# ----------------------------------- Create Batch Posting ------------------------------------------
# ----------------------------------- Create Batch Posting ------------------------------------------

def create_batch_posting():
    # Wait for the page to load 
    time.sleep(1)
    root.withdraw()  # Minimize the Tkinter window
    # Select the web element for opening oracle software for creating batch
    pg.press("tab", presses=14)
    pg.press("enter")
    time.sleep(1)
    pg.press("tab", presses=3)
    pg.press("enter")
    
    # Wait for the software download 
    time.sleep(8)
    pg.hotkey("alt", "i")
    pg.press("esc")
    pg.press("enter")
    # messagebox.showinfo("Create Batch Posting", "Creating Batch Posting...")
    time.sleep(8)
    root.deiconify()  # Show the Tkinter window after the login process completes
    
    
# ----------------------------------- Check Batch Report  -------------------------------------------
# ----------------------------------- Check Batch Report  -------------------------------------------
def create_new_request_production_manager():
    time.sleep(1)
    pg.hotkey("alt", "v")
    pg.press("r")
    pg.hotkey("alt", "n")
    time.sleep(5)

def submit_form():
    pg.hotkey("alt", "m")
    time.sleep(3)
    pg.hotkey("alt", "n")
    time.sleep(3)
    pg.hotkey("alt", "i")

def refresh_and_get():
    time.sleep(1)
    pg.hotkey("alt", "r")
    time.sleep(2)
    pg.hotkey("alt", "p")

def check_batch_report():
    
    create_batch_posting()
    root.withdraw()  # Minimize the Tkinter window
    create_new_request_production_manager()
    pg.write("SSGIL Packer Wise Bag Cement Production")
    pg.press("tab")
    time.sleep(2)
    pg.write(batch_report_from_date)
    time.sleep(.5)
    pg.press("tab")
    pg.write(batch_report_to_date)
    time.sleep(.5)
    pg.hotkey("alt", "o")
    time.sleep(1)
    # pg.hotkey("alt", "m")
    # time.sleep(3)
    # pg.hotkey("alt", "n")
    # time.sleep(3)
    # pg.hotkey("alt", "i")
    # time.sleep(5)
    # pg.hotkey("alt", "r")
    # time.sleep(2)
    # pg.hotkey("alt", "p")
    submit_form()
    refresh_and_get()
    
    print("Check Packer wise batch report.")
    
    # messagebox.showinfo("Check Batch Report", "Checking Batch Report...")
    time.sleep(1)
    root.deiconify()  # Show the Tkinter window after the login process completes

   



# ----------------------------------- Download OHD --------------------------------------------------
# ----------------------------------- Download OHD --------------------------------------------------

    
def download_ohd():
    # # Wait for the page to load 
    # time.sleep(1)
    # root.withdraw()  # Minimize the Tkinter window
    # # Select the web element for opening oracle software for creating batch
    # pg.press("tab", presses=14)
    # pg.press("enter")
    # time.sleep(1)
    # pg.press("tab", presses=3)
    # pg.press("enter")
    
    # # Wait for the software download 
    # time.sleep(8)
    # pg.hotkey("alt", "i")
    # pg.press("esc")
    # pg.press("enter")
    create_batch_posting()
    root.withdraw()  # Minimize the Tkinter window
    
    # Check On Hand Details

    # This hidden part is now included in the function "create_new_request_production_part()"
    # time.sleep(1)
    # pg.hotkey("alt", "v")
    # pg.press("r")
    # pg.hotkey("alt", "n")
    # time.sleep(5)
    create_new_request_production_manager()
    # No need this part due to directly writing "SSGIL Item Onhand Details" in the field----- open ---------
    # pg.write("S")
    # pg.press("tab")
    # time.sleep(5)
    # pg.press("down", presses=5)  
    # time.sleep(2)
    # pg.press("enter")
    # time.sleep(1)
    # pg.hotkey("ctrl", "c")
    # pg.press("tab", presses=3)
    # pg.press("enter")
    # No need this part due to directly writing "SSGIL Item Onhand Details" in the field----- Close ---------
    pg.write("SSGIL Item Onhand Details")
    pg.press("tab")
    time.sleep(2)
    pg.hotkey("ctrl", "c")
    time.sleep(1)
    pg.hotkey("alt", "o")
    time.sleep(1)
    # pg.hotkey("alt", "m")
    # time.sleep(3)
    # pg.hotkey("alt", "n")
    # time.sleep(3)
    # pg.hotkey("alt", "i")
    # time.sleep(5)
    # pg.hotkey("alt", "r")
    # time.sleep(2)
    # pg.hotkey("alt", "p")
    submit_form()
    time.sleep(5)
    refresh_and_get()
    
    print("Downloading the On Hand Details ")
    # messagebox.showinfo("Download OHD", "Download OHD...")
    time.sleep(1)
    root.deiconify()  # Show the Tkinter window after the login process completes
    




# ----------------------------------- Check OHD -----------------------------------------------------

def check_ohd():
    # download_ohd()
    messagebox.showinfo("Check OHD", "Checking OHD...")


# ----------------------------------- Download ILS --------------------------------------------------

def download_ils():
    # download_ils()
    time.sleep(1)
    root.withdraw()  # Minimize the Tkinter window
    select_move_order_create()
    software_download()
    time.sleep(5)
    create_new_request_inventory()

    pg.write("SSGIL Item Ledger Summury")
    time.sleep(.5)
    pg.press("tab")
    time.sleep(2)
    pg.write(ils_date_from)
    time.sleep(.5)
    pg.press("tab")
    pg.write(ils_date_to)    
    # pg.hotkey("ctrl", "c")
    time.sleep(1)
    pg.hotkey("alt", "o")
    time.sleep(1)
    submit_form()
    time.sleep(12)
    refresh_and_get()
    
    
    print("Downloading the Item Ledger Summery ")
    # messagebox.showinfo("Download ILS", "Download ILS...")
    time.sleep(1)
    root.deiconify()  # Show the Tkinter window after the login process completes




# ----------------------------------- Check ILS -----------------------------------------------------

def check_ils():
    messagebox.showinfo("Check ILS", "Checking ILS...")



# ----------------------------------- Check M_Transaction -------------------------------------------

def check_m_transaction():
    messagebox.showinfo("Check M_Transaction", "Checking M_Transaction...")



def create_gui():
    def button_click(button_name):
        if button_name == "Log In":
            log_in()
        elif button_name == "Create MO":
            create_mo()
        elif button_name == "Create Batch Posting":
            create_batch_posting()
        elif button_name == "Check Batch Report":
            check_batch_report()
        elif button_name == "Download OHD":
            download_ohd()
        elif button_name == "Check OHD":
            check_ohd()
        elif button_name == "Download ILS":
            download_ils()
        elif button_name == "Check ILS":
            check_ils()
        elif button_name == "Check M_Transaction":
            check_m_transaction()


    buttons = [
        "Log In",
        "Create MO",
        "Create Batch Posting",
        "Check Batch Report",
        "Download OHD",
        "Check OHD",
        "Download ILS",
        "Check ILS",
        "Check M_Transaction"
        
    ]

    for button_name in buttons:
        button = tk.Button(root, text=button_name, command=lambda btn=button_name: button_click(btn))
        button.pack(pady=5)

if __name__ == "__main__":
    firefox_shortcut_path = r"C:\ProgramData\Microsoft\Windows\Start Menu\Programs\Mozilla Firefox.lnk"
    root = tk.Tk()
    root.title("Code Run")
    create_gui()
    root.mainloop()
# Out:
# Login Info Username: 5638
# Password: Ripon
# 5638
# Mozilla Firefox is now opening...
# Mozilla Firefox is now opening...
# Mozilla Firefox is now opening...
# ...
