# %%
# # # Title: Automate the process to Check On Hand Details from Oracle

### #Check On Hand Details Report

### # Version 1

# # System Details
# # Miniconda 3
# # jupyter lab
# # Environment : myenv
# # This file Path : pypy/OnHandDetails/CheckOnHandDetails.ipynb
# # Sharable Link: http://localhost:8888/lab/tree/pypy/OnHandDetails/CheckOnHandDetails.ipynb
# # Download Link: http://localhost:8888/files/pypy/OnHandDetails/CheckOnHandDetails.ipynb?_xsrf=2%7C508c4078%7C5679e52602d1279d22ecc3e2a51f1eb2%7C1708620541
# # Creator : Ripon Sarkar


import pyautogui as pg
import time
import subprocess

userName = "5638"
password = "ripon"


#Open dedicated Browser

firefox_shortcut_path = r"C:\ProgramData\Microsoft\Windows\Start Menu\Programs\Mozilla Firefox.lnk"

def open_firefox_dedicated_browser(shortcut_path):
    try:
        subprocess.Popen([shortcut_path], shell=True)
        print("Mozilla Firefox is now opening...")
    except Exception as e:
        print(f"Error: {e}")

# Example usage:
open_firefox_dedicated_browser(firefox_shortcut_path)


#Load The webpage
time.sleep (8)

# Login the website
pg.write (userName)
pg.press ("tab")
pg.write (password)
pg.press ("tab")
pg.press ("enter")

# Wait for the page to load 
time.sleep(2)

# Select the web element for opening oracle software for creating batch
pg.press ("tab", presses = 14)
pg.press ("enter")
time.sleep (1)
pg.press ("tab", presses = 3)
pg.press ("enter")



# Wait for the software download 
time.sleep(8)
pg.hotkey ("alt","i")
pg.press ("esc")
pg.press ("enter")


# Check On Hand Details
time.sleep (8)
pg.hotkey ("alt", "v")
pg.press ("r")
pg.hotkey ("alt","n")
# pg.press ("enter")
time.sleep (5)
pg.write ("S")
pg.press ("tab")
time.sleep (5)
pg.press ("down", presses =5)
time.sleep (2)
pg.press ("enter")
time.sleep (1)
pg.hotkey ("ctrl", "c")
pg.press ("tab", presses = 3)
pg.press ("enter")
#--------------- ok till now
time.sleep (3)
pg.hotkey ("alt" , "m")
time.sleep (3)
pg.hotkey ("alt" , "n")
time.sleep (3)
pg.hotkey ("alt" , "i")
time.sleep (3)
pg.hotkey ("alt" , "r")
time.sleep (2)
pg.hotkey ("alt" , "p")

print ("Downloading the On Hand Details ")
# Out:
# Mozilla Firefox is now opening...
